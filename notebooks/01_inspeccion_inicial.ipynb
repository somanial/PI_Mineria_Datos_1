# %%
# !pip install pandas
import pandas as pd

# 1. Cargo el archivo JSON en la carpeta raw
df = pd.read_json("../data/raw/streaming_users_dirty.json")

# 2. Le pido a la computadora que nos muestre las primeras filas
df.head()
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.8 MB 3.3 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.8 MB 3.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.8 MB 4.6 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 5.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.8 MB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 4.6 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.8 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 4.1 MB/s eta 0:00:01
# ...

# %%
# 3. Ver el tamaño total (filas y columnas)
print("--- TAMAÑO DEL DATASET ---")
print(f"Filas: {df.shape[0]} | Columnas: {df.shape[1]}\n")

# 4. Ver qué columnas hay y si tienen datos nulos/vacíos
print("--- INFORMACIÓN GENERAL Y VACÍOS ---")
df.info()
# Out:
# --- TAMAÑO DEL DATASET ---
# Filas: 8160 | Columnas: 8
#
# --- INFORMACIÓN GENERAL Y VACÍOS ---
# <class 'pandas.DataFrame'>
# RangeIndex: 8160 entries, 0 to 8159
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   user_id                   8160 non-null   int64
#  1   age                       8160 non-null   int64
#  2   subscription_plan         8160 non-null   str
#  3   monthly_watch_time_mins   7967 non-null   float64
#  4   country                   8160 non-null   str
#  5   favorite_genre            7920 non-null   str
#  6   last_login_date           7840 non-null   str
#  7   customer_support_tickets  8160 non-null   int64
# dtypes: float64(1), int64(3), str(4)
# memory usage: 510.1 KB

# %%
# Ver estadísticas básicas de las columnas numéricas (edad, tiempo, tickets de soporte)
df.describe()
# Out:
#             user_id          age  monthly_watch_time_mins  \
# count   8160.000000  8160.000000              7967.000000
# mean   13995.433824    34.096814              1107.346153
# std     2310.810660    14.511304              5310.442604
# min    10000.000000    -5.000000              -120.000000
# 25%    11987.750000    25.000000               489.200000
# 50%    13998.500000    33.000000               757.400000
# 75%    15997.250000    42.000000              1045.700000
# max    17999.000000   150.000000             99999.000000
#
#        customer_support_tickets
# count               8160.000000
# mean                   1.800980
# std                   11.334969
# min                   -1.000000
# 25%                    0.000000
# 50%                    1.000000
# 75%                    1.000000
# max                  150.000000
